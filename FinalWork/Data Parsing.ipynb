# %%
import pandas as pd
import numpy as np

# %%
week1 = pd.read_csv("./Data/AstroYWeek1DataSet.csv")
week2 = pd.read_csv("./Data/AstroYWeek2DataSet(Corrected).csv")
week3 = pd.read_csv("./Data/AstroYWeek3DataSet.csv")
week4 = pd.read_csv("./Data/AstroYWeek4DataSet.csv")

# %%
weeks = [week1,week2,week3,week4]
for week in weeks:
    print(week.describe())
# Out:
#         NORAD_CAT_ID    MEAN_MOTION   ECCENTRICITY    INCLINATION  \
# count  101799.000000  101799.000000  101799.000000  101799.000000
# mean    50489.865883      13.814968       0.001982      86.441973
# std     29136.266258       4.310947       0.003440      19.371962
# min        43.000000       0.057840       0.000000       0.047100
# 25%     24965.000000      14.883887       0.000519      82.479350
# 50%     51035.000000      15.121627       0.001119      97.431500
# 75%     75749.000000      15.251921       0.001816      97.715300
# max     99857.000000      16.566982       0.052344     144.559200
#
#        RA_OF_ASC_NODE  ARG_OF_PERICENTER   MEAN_ANOMALY  SEMIMAJOR_AXIS  \
# count   101799.000000      101799.000000  101799.000000   101799.000000
# mean       166.141870         163.618218     177.457484     6900.840338
# std        118.689105         115.449894     108.801757       81.244910
# min          0.000400           0.000000       0.001700     6499.893000
# ...

# %%
all_data = pd.concat(weeks)
all_data.to_csv("./Data/AllWeeks.csv")
