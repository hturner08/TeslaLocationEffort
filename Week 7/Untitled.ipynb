# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("./thedata.csv")

# %%
data.head(10)
# Out:
#    NORAD_CAT_ID                EPOCH  MEAN_MOTION  ECCENTRICITY  INCLINATION  \
# 0             5   2019-11-08 8:39:00     5.726962      0.487162      51.6845
# 1             5  2019-11-12 13:09:00     5.727188      0.487112      51.6861
# 2             5  2019-11-14 11:13:00     5.727285      0.487099      51.6867
# 3             6   2019-11-12 8:36:00    13.973694      0.001726      82.5330
# 4             6   2019-11-13 8:39:00    13.973714      0.001728      82.5330
# 5            20  2019-11-07 22:58:00    12.623774      0.000764      82.5852
# 6            20  2019-11-08 12:36:00    12.623774      0.000761      82.5848
# 7            20  2019-11-09 11:23:00    12.623773      0.000759      82.5848
# 8            20  2019-11-09 22:32:00    12.623773      0.000758      82.5848
# 9            20  2019-11-10 12:25:00    12.623773      0.000756      82.5848
#
#    RA_OF_ASC_NODE  ARG_OF_PERICENTER  MEAN_ANOMALY  SEMIMAJOR_AXIS   PERIOD  \
# ...

# %% [markdown]
# ## Building Recurrent Neural Network
